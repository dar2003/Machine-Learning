# %% [markdown]
# **Logistic Regression is a statistical and machine learning algorithm used for binary or multi-class classification problems. It predicts the probability of a dependent variable belonging to a particular class based on one or more independent variables.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("D:/data science/DATASETS/job.csv")
df.head(20)
# Out:
#     Years  result
# 0      22       0
# 1      25       0
# 2      47       1
# 3      52       0
# 4      46       1
# 5      56       1
# 6      55       0
# 7      60       1
# 8      62       1
# 9      61       1
# 10     18       0
# 11     28       0
# 12     27       0
# 13     29       0
# 14     49       1
# 15     55       1
# 16     25       1
# 17     58       1
# 18     19       0
# 19     18       0

# %%
x=df[['Years']]
y=df['result']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,train_size=0.8,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
print(X_test)
# Out:
#     Years
# 17     58
# 14     49
# 18     19
# 3      52
# 23     45
# 10     18

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([1, 1, 0, 1, 1, 0], dtype=int64)

# %%
y_test
# Out:
# 17    1
# 14    1
# 18    0
# 3     0
# 23    1
# 10    0
# Name: result, dtype: int64

# %%
model.score(X_test,y_test)
# Out:
# 0.8333333333333334

# %%
import seaborn as sns
sns.regplot(x=X_test, y=y_test, logistic=True)
# Out:
# <Axes: xlabel='Years', ylabel='result'>

# %%
sns.regplot(x=x, y=y, logistic=True, ci=None)
# Out:
# <Axes: xlabel='Years', ylabel='result'>
